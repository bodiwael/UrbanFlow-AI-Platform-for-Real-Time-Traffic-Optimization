# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 31.8 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="fJmfdkItlytewveAMP6Q")
project = rf.workspace("attar").project("cpstone")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 19.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 86.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 133.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to cpstone-1 in yolov11:: 100%|██████████| 584/584 [00:00<00:00, 9100.17it/s]

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/content/cpstone-1/data.yaml epochs=50 imgsz=640
# Out:
# Ultralytics 8.3.252 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from google.colab import files

# Compress the folder before downloading
# !zip -r /content/runs_detect_train.zip /content/runs/detect/train2

# Download the compressed file
files.download('/content/runs_detect_train.zip')
# Out:
#   adding: content/runs/detect/train2/ (stored 0%)
#   adding: content/runs/detect/train2/BoxF1_curve.png (deflated 10%)
#   adding: content/runs/detect/train2/labels.jpg (deflated 36%)
#   adding: content/runs/detect/train2/val_batch1_pred.jpg (deflated 6%)
#   adding: content/runs/detect/train2/confusion_matrix_normalized.png (deflated 32%)
#   adding: content/runs/detect/train2/train_batch521.jpg (deflated 5%)
#   adding: content/runs/detect/train2/val_batch0_pred.jpg (deflated 7%)
#   adding: content/runs/detect/train2/BoxP_curve.png (deflated 16%)
#   adding: content/runs/detect/train2/weights/ (stored 0%)
#   adding: content/runs/detect/train2/weights/best.pt (deflated 9%)
#   adding: content/runs/detect/train2/weights/last.pt (deflated 9%)
#   adding: content/runs/detect/train2/args.yaml (deflated 53%)
#   adding: content/runs/detect/train2/val_batch1_labels.jpg (deflated 6%)
#   adding: content/runs/detect/train2/train_batch2.jpg (deflated 1%)
# ...
